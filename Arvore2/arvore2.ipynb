# %%
import pandas as pd
from tabulate import tabulate

caminho_do_csv = 'fifa_players.csv'

df = pd.read_csv(caminho_do_csv)

#print(tabulate(df, headers='keys', tablefmt='grid'))

#exibir apenas as primeiras linhas
#print(tabulate(df.head(), headers='keys', tablefmt='grid'))

# %%
# filtrado = df.query("overall_rating == 47 and age == 20")

#filtrado = df[(df['overall_rating'] == 75) & (df['age'] == 20) & (df['potential'] == 84)]

#filtrado = df.query("80 <= overall_rating <= 83")

filtrado = df[(df['positions'] == 'GK')]

print(tabulate(filtrado, headers='keys', tablefmt='grid'))
# Out:
# +-------+------------------------+-----------------------------------------+--------------+-------+-------------+--------------+-------------+---------------------+------------------+-------------+---------------+-------------+------------------+---------------------------------+------------------+--------------------+-------------+-----------------------+-------------------------+-------------------+--------------------------+--------------------------+------------+-------------+--------------------+-----------------+-----------+-------------+---------+---------------------+----------------+----------------+----------------+----------------+-----------+-------------+-----------+--------------+-----------+-----------+------------+--------------+--------------+-----------------+---------------+----------+-------------+-------------+-----------+-------------------+------------------+
# ...

# %%
import pandas as pd
from tabulate import tabulate

df = pd.read_csv(caminho_do_csv)

def arvore_decisao():
    def filtrar_dataframe(filtro, coluna):
        return df[df[coluna].str.contains(filtro, case=False, na=False)]

    def aplicar_intervalos(df, coluna, valor):
        df_copy = df.copy()
        
        # Tentando converter a coluna para valores numéricos, e gerando erro 'coerce' em caso de falha.
        df_copy[coluna] = pd.to_numeric(df_copy[coluna], errors='coerce')
        
        
        if isinstance(valor, (int, float)):
            return df_copy[(df_copy[coluna] >= valor - 3) & (df_copy[coluna] <= valor + 3)]
        else:
            # Se o valor não for numérico, apenas retornar o dataframe sem filtro
            print(f"Valor inválido para a coluna {coluna}, apenas valores numéricos são aceitos.")
            return df_copy

    def jogadores_proximos(df, criterios, posicao_filtro):
        df_posicao = df[df['positions'].str.contains(posicao_filtro, case=False, na=False)]
        df_posicao = df_posicao.copy()
        df_posicao['distancia'] = df_posicao.apply(
            lambda row: sum(abs(row[crit] - val) for crit, val in criterios.items() if pd.notnull(row[crit])),
            axis=1
        )
        return df_posicao.sort_values(by='distancia').head(10)

    posicao = input("Qual posição geral deseja (Defensor, Atacante, Meia)? ").strip().capitalize()
    posicao_filtro = ""

    if posicao == "Defensor":
        tipo_defensor = input("Qual tipo de defensor (GK, CB, RB, LB)? ").strip().upper()
        posicao_filtro = tipo_defensor
        if tipo_defensor == "CB":
            altura = input("Qual é a altura mínima em cm? ").strip()
            heading_accuracy = input("Qual é o valor mínimo para heading_accuracy? ").strip()
            jumping = input("Qual é o valor mínimo para jumping? ").strip()
            strength = input("Qual é o valor mínimo para strength? ").strip()
            
            
            criterios = {}
            if altura.isdigit():
                criterios['height_cm'] = int(altura)
            if heading_accuracy.isdigit():
                criterios['heading_accuracy'] = int(heading_accuracy)
            if jumping.isdigit():
                criterios['jumping'] = int(jumping)
            if strength.isdigit():
                criterios['strength'] = int(strength)

        elif tipo_defensor in ["RB", "LB"]:
            crossing = input("Qual é o valor mínimo para crossing? ").strip()
            acceleration = input("Qual é o valor mínimo para acceleration? ").strip()
            stamina = input("Qual é o valor mínimo para stamina? ").strip()
            
            
            criterios = {}
            if crossing.isdigit():
                criterios['crossing'] = int(crossing)
            if acceleration.isdigit():
                criterios['acceleration'] = int(acceleration)
            if stamina.isdigit():
                criterios['stamina'] = int(stamina)

        elif tipo_defensor == "GK":
            reflexos = input("Qual é o valor mínimo para reações (reactions)? ").strip()
            altura = input("Qual é a altura mínima em cm? ").strip()
            
            
            criterios = {}
            if reflexos.isdigit():
                criterios['reactions'] = int(reflexos)
            if altura.isdigit():
                criterios['height_cm'] = int(altura)

    elif posicao == "Atacante":
        finishing = input("Qual é o valor mínimo para finalização (finishing)? ").strip()
        posicao_filtro = "ST|LW|RW"
        if 'ST' in posicao_filtro:
            heading_accuracy = input("Qual é o valor mínimo para heading_accuracy? ").strip()
            ball_control = input("Qual é o valor mínimo para ball_control? ").strip()
            
            
            criterios = {}
            if finishing.isdigit():
                criterios['finishing'] = int(finishing)
            if heading_accuracy.isdigit():
                criterios['heading_accuracy'] = int(heading_accuracy)
            if ball_control.isdigit():
                criterios['ball_control'] = int(ball_control)
        else:
            dribbling = input("Qual é o valor mínimo para dribbling? ").strip()
            acceleration = input("Qual é o valor mínimo para acceleration? ").strip()
            
            
            criterios = {}
            if finishing.isdigit():
                criterios['finishing'] = int(finishing)
            if dribbling.isdigit():
                criterios['dribbling'] = int(dribbling)
            if acceleration.isdigit():
                criterios['acceleration'] = int(acceleration)

    elif posicao == "Meia":
        posicao_especifica = input("Qual tipo de meia (CM, CAM, CDM, RM, LM)? ").strip().upper()
        posicao_filtro = posicao_especifica
        if posicao_especifica == "CM" or posicao_especifica == "CAM":
            preferred_foot = input("Qual pé preferido (left, right)? ").strip().capitalize()
            dribbling = input("Qual é o valor mínimo para dribbling? ").strip()
            long_passing = input("Qual é o valor mínimo para long_passing? ").strip()
            vision = input("Qual é o valor mínimo para vision? ").strip()
            
            
            criterios = {}
            if dribbling.isdigit():
                criterios['dribbling'] = int(dribbling)
            if long_passing.isdigit():
                criterios['long_passing'] = int(long_passing)
            if vision.isdigit():
                criterios['vision'] = int(vision)

        elif posicao_especifica == "CDM":
            reactions = input("Qual é o valor mínimo para reactions? ").strip()
            strength = input("Qual é o valor mínimo para strength? ").strip()
            aggression = input("Qual é o valor mínimo para aggression? ").strip()
            interceptions = input("Qual é o valor mínimo para interceptions? ").strip()
            
            
            criterios = {}
            if reactions.isdigit():
                criterios['reactions'] = int(reactions)
            if strength.isdigit():
                criterios['strength'] = int(strength)
            if aggression.isdigit():
                criterios['aggression'] = int(aggression)
            if interceptions.isdigit():
                criterios['interceptions'] = int(interceptions)

        elif posicao_especifica in ["RM", "LM"]:
            acceleration = input("Qual é o valor mínimo para acceleration? ").strip()
            dribbling = input("Qual é o valor mínimo para dribbling? ").strip()
            long_passing = input("Qual é o valor mínimo para long_passing? ").strip()
            
            
            criterios = {}
            if acceleration.isdigit():
                criterios['acceleration'] = int(acceleration)
            if dribbling.isdigit():
                criterios['dribbling'] = int(dribbling)
            if long_passing.isdigit():
                criterios['long_passing'] = int(long_passing)

    else:
        print("Posição inválida. Por favor, reinicie o programa.")
        return

    age = input("Qual é a faixa etária do jogador? ").strip()
    overall_rating = input("Qual é a classificação geral mínima (overall_rating)? ").strip()
    
    
    criterios.update({'age': int(age) if age.isdigit() else None, 'overall_rating': int(overall_rating) if overall_rating.isdigit() else None})

    if age and int(age) < 21:
        potential = input("Qual é o potencial mínimo (potential)? ").strip()
        criterios.update({'potential': int(potential) if potential.isdigit() else None})

    df_filtrado = df.copy()
    for criterio, valor in criterios.items():
        if valor is not None:
            df_filtrado = aplicar_intervalos(df_filtrado, criterio, valor)

    # Filtros de posição
    jogadores_posicao = jogadores_proximos(df_filtrado, criterios, posicao_filtro)
    
    # Exibindo jogadores encontrados com a função tabulate
    print(tabulate(jogadores_posicao[['name', 'age', 'positions', 'overall_rating']], headers='keys', tablefmt='pretty'))

arvore_decisao()
# Out:
# +-------+------------+-----+-----------+----------------+
# |       |    name    | age | positions | overall_rating |
# +-------+------------+-----+-----------+----------------+
# |  32   |    Kepa    | 24  |    GK     |       84       |
# | 17865 |  M. Perin  | 26  |    GK     |       84       |
# | 17758 | B. Lecomte | 27  |    GK     |       82       |
# +-------+------------+-----+-----------+----------------+
